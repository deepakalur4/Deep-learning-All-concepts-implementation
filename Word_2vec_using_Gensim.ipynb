# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import gensim

# %%
df=pd.read_csv("https://raw.githubusercontent.com/aws-samples/aws-machine-learning-university-accelerated-nlp/master/data/examples/AMAZON-REVIEW-DATA-CLASSIFICATION.csv")

# %%
df.head()
# Out:
#                                           reviewText  ... isPositive
# 0  PURCHASED FOR YOUNGSTER WHO\nINHERITED MY "TOO...  ...        1.0
# 1                              unable to open or use  ...        0.0
# 2   Waste of money!!! It wouldn't load to my system.  ...        0.0
# 3  I attempted to install this OS on two differen...  ...        0.0
# 4  I've spent 14 fruitless hours over the past tw...  ...        0.0
#
# [5 rows x 6 columns]

# %%
df["reviewText"]=df["reviewText"].astype(str).apply(gensim.utils.simple_preprocess)

# %%
df.head()
# Out:
#                                           reviewText  ... isPositive
# 0  [purchased, for, youngster, who, inherited, my...  ...        1.0
# 1                        [unable, to, open, or, use]  ...        0.0
# 2  [waste, of, money, it, wouldn, load, to, my, s...  ...        0.0
# 3  [attempted, to, install, this, os, on, two, di...  ...        0.0
# 4  [ve, spent, fruitless, hours, over, the, past,...  ...        0.0
#
# [5 rows x 6 columns]

# %%
model=gensim.models.Word2Vec(df["reviewText"],min_count=2,workers=4)

# %%
model.wv.most_similar("good")
# Out:
# [('decent', 0.75848788022995),
#  ('great', 0.7143431901931763),
#  ('cheap', 0.6517404317855835),
#  ('bad', 0.6322393417358398),
#  ('fantastic', 0.6157630681991577),
#  ('nice', 0.6077818274497986),
#  ('perfect', 0.5973283052444458),
#  ('cool', 0.5946765542030334),
#  ('tough', 0.5785448551177979),
#  ('reasonable', 0.5748388767242432)]

# %%
model.wv.similarity(w1="good",w2="great")
# Out:
# 0.7143433
